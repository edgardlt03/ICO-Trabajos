# %% [markdown]
# <a href="https://colab.research.google.com/github/edgardlt03/ICO-Trabajos/blob/main/Participaci%C3%B3n_mayo_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai -q

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
SYSTEM_MESSAGE = "You are a chatbot. You will have a conversation with a user. Be friendly and concise"

URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
KEY = "AIzaSyBS06U0VRoieOuCsWa-JgMum4fnO01bsVs"
MODEL = "gemini-flash-latest"

client = OpenAI(
    base_url=URL,
    api_key=KEY,
)

messages = [
    {"role": "system", "content": SYSTEM_MESSAGE}
]

print(f"Chatting with {MODEL} model at {URL}\n")

while True:
    message = input("> ")

    if message.lower() in ("salir", "exit", "quit"):
        print("Bye!")
        break

    messages.append({"role": "user", "content": message})

    response = client.chat.completions.create(
        model=MODEL,
        messages=messages
    )

    assistant_reply = response.choices[0].message.content

    if assistant_reply:
        print(assistant_reply)
        messages.append({"role": "assistant", "content": assistant_reply})
# Out:
# Chatting with gemini-flash-latest model at https://generativelanguage.googleapis.com/v1beta/openai/
#
# > hola soy edgar
# ¡Hola, Edgar! Un gusto saludarte. ¿En qué puedo ayudarte hoy?
# > como me llamo
# Te llamas Edgar. ¿En qué te puedo ayudar hoy?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3426/2396582587.py in <cell line: 0>()
#      20
#      21 while True:
# ---> 22     message = input("> ")
#      23
#      24     if message.lower() in ("salir", "exit", "quit"):
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
